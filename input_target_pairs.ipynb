# %%
with open("data/the-verdict.txt", "r") as f:
    raw = f.read()

# %%
import tiktoken
tokenizer = tiktoken.get_encoding("gpt2")

# %%
txt = tokenizer.encode(raw)
len(txt)
# Out:
# 5145

# %%
sample_txt = txt[:50]
len(sample_txt)
# Out:
# 50

# %%
context_size = 5

x = sample_txt[:context_size]
y = sample_txt[1:context_size+1]

# %%
print(f"x : {x}")
print(f"y :      {y}")
# Out:
# x : [40, 367, 2885, 1464, 1807]
# y :      [367, 2885, 1464, 1807, 3619]

# %%
for i in range(1, context_size+1):
    x_i = sample_txt[:i]
    y_i = sample_txt[i]
    
    print(x_i, "---", y_i)
# Out:
# [40] --- 367
# [40, 367] --- 2885
# [40, 367, 2885] --- 1464
# [40, 367, 2885, 1464] --- 1807
# [40, 367, 2885, 1464, 1807] --- 3619

# %%
for i in range(1, context_size+1):
    x_i = sample_txt[:i]

    y_i = sample_txt[i]
    
    print(tokenizer.decode(x_i), "---", tokenizer.decode([y_i]))
# Out:
# I ---  H
# I H --- AD
# I HAD ---  always
# I HAD always ---  thought
# I HAD always thought ---  Jack

# %%
! pip install torch
# Out:
# Requirement already satisfied: torch in /home/kid/miniconda3/lib/python3.13/site-packages (2.9.0)
# Requirement already satisfied: filelock in /home/kid/miniconda3/lib/python3.13/site-packages (from torch) (3.19.1)
# Requirement already satisfied: typing-extensions>=4.10.0 in /home/kid/miniconda3/lib/python3.13/site-packages (from torch) (4.12.2)
# Requirement already satisfied: setuptools in /home/kid/miniconda3/lib/python3.13/site-packages (from torch) (78.1.1)
# Requirement already satisfied: sympy>=1.13.3 in /home/kid/miniconda3/lib/python3.13/site-packages (from torch) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /home/kid/miniconda3/lib/python3.13/site-packages (from torch) (3.5)
# Requirement already satisfied: jinja2 in /home/kid/miniconda3/lib/python3.13/site-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /home/kid/miniconda3/lib/python3.13/site-packages (from torch) (2025.9.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in /home/kid/miniconda3/lib/python3.13/site-packages (from torch) (12.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in /home/kid/miniconda3/lib/python3.13/site-packages (from torch) (12.8.90)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in /home/kid/miniconda3/lib/python3.13/site-packages (from torch) (12.8.90)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /home/kid/miniconda3/lib/python3.13/site-packages (from torch) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in /home/kid/miniconda3/lib/python3.13/site-packages (from torch) (12.8.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in /home/kid/miniconda3/lib/python3.13/site-packages (from torch) (11.3.3.83)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in /home/kid/miniconda3/lib/python3.13/site-packages (from torch) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in /home/kid/miniconda3/lib/python3.13/site-packages (from torch) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in /home/kid/miniconda3/lib/python3.13/site-packages (from torch) (12.5.8.93)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /home/kid/miniconda3/lib/python3.13/site-packages (from torch) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /home/kid/miniconda3/lib/python3.13/site-packages (from torch) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.3.20 in /home/kid/miniconda3/lib/python3.13/site-packages (from torch) (3.3.20)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in /home/kid/miniconda3/lib/python3.13/site-packages (from torch) (12.8.90)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in /home/kid/miniconda3/lib/python3.13/site-packages (from torch) (12.8.93)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in /home/kid/miniconda3/lib/python3.13/site-packages (from torch) (1.13.1.3)
# Requirement already satisfied: triton==3.5.0 in /home/kid/miniconda3/lib/python3.13/site-packages (from torch) (3.5.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/kid/miniconda3/lib/python3.13/site-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/kid/miniconda3/lib/python3.13/site-packages (from jinja2->torch) (3.0.2)

# %%
from torch.utils.data import Dataset, DataLoader

# %%
class GPTV1(Dataset):
    def __init__(self, txt, tokenizer, max_len, stride):
        self.input_ids = []
        self.target_ids = []

        token_ids = tokenizer.encode(txt, allowed_special={"|endoftext|"})

        for i in range(0, len(token_ids) - max_len, stride):
            ip_chunk = token_ids[i : i + max_len]
            target_chunk = token_ids[i + 1 : i + max_len + 1]
            self.input_ids.append(torch.tensor(ip_chunk))
            self.target_ids.append(torch.tensor(target_chunk))

    def __len__(self):
        return len(self.input_ids)

    def __getitem__(self, idx):
        return self.input_ids[idx], self.target_ids[idx]

# %%
def create_dataloader_v1(txt, batch_size=4, max_len=256, stride=128,
                     shuffle=True, drop_last=True, num_workers=0):
    
    tokenizer = tiktoken.get_encoding("gpt2")
    
    dataset = GPTV1(txt, tokenizer, max_len, stride)

    dataloader = DataLoader(
        dataset,
        batch_size=batch_size,
        shuffle=shuffle,
        drop_last=drop_last,
        num_workers=num_workers
    )

    return dataloader

# %%
dataloader = create_dataloader_v1(
    raw, batch_size=1, max_len=4, stride=1, shuffle=True
)
dataloader.dataset.target_ids
# Out:
# [tensor([ 367, 2885, 1464, 1807]),
#  tensor([2885, 1464, 1807, 3619]),
#  tensor([1464, 1807, 3619,  402]),
#  tensor([1807, 3619,  402,  271]),
#  tensor([ 3619,   402,   271, 10899]),
#  tensor([  402,   271, 10899,  2138]),
#  tensor([  271, 10899,  2138,   257]),
#  tensor([10899,  2138,   257,  7026]),
#  tensor([ 2138,   257,  7026, 15632]),
#  tensor([  257,  7026, 15632,   438]),
#  tensor([ 7026, 15632,   438,  2016]),
#  tensor([15632,   438,  2016,   257]),
#  tensor([ 438, 2016,  257,  922]),
#  tensor([2016,  257,  922, 5891]),
#  tensor([ 257,  922, 5891, 1576]),
#  tensor([ 922, 5891, 1576,  438]),
#  tensor([5891, 1576,  438,  568]),
#  tensor([1576,  438,  568,  340]),
#  tensor([438, 568, 340, 373]),
#  tensor([568, 340, 373, 645]),
#  tensor([ 340,  373,  645, 1049]),
#  tensor([ 373,  645, 1049, 5975]),
#  tensor([ 645, 1049, 5975,  284]),
#  tensor([1049, 5975,  284,  502]),
#  tensor([5975,  284,  502,  284]),
#  tensor([ 284,  502,  284, 3285]),
#  tensor([ 502,  284, 3285,  326]),
#  tensor([ 284, 3285,  326,   11]),
#  tensor([3285,  326,   11,  287]),
#  tensor([326,  11, 287, 262]),
#  tensor([  11,  287,  262, 6001]),
#  tensor([ 287,  262, 6001,  286]),
#  tensor([ 262, 6001,  286,  465]),
#  tensor([ 6001,   286,   465, 13476]),
#  tensor([  286,   465, 13476,    11]),
#  tensor([  465, 13476,    11,   339]),
#  tensor([13476,    11,   339,   550]),
#  tensor([  11,  339,  550, 5710]),
#  tensor([ 339,  550, 5710,  465]),
#  tensor([  550,  5710,   465, 12036]),
#  tensor([ 5710,   465, 12036,    11]),
#  tensor([  465, 12036,    11,  6405]),
#  tensor([12036,    11,  6405,   257]),
#  tensor([  11, 6405,  257, 5527]),
#  tensor([ 6405,   257,  5527, 27075]),
#  tensor([  257,  5527, 27075,    11]),
#  tensor([ 5527, 27075,    11,   290]),
#  tensor([27075,    11,   290,  4920]),
#  tensor([  11,  290, 4920, 2241]),
#  tensor([ 290, 4920, 2241,  287]),
#  tensor([4920, 2241,  287,  257]),
#  tensor([2241,  287,  257, 4489]),
#  tensor([ 287,  257, 4489,   64]),
#  tensor([ 257, 4489,   64,  319]),
#  tensor([4489,   64,  319,  262]),
#  tensor([   64,   319,   262, 34686]),
#  tensor([  319,   262, 34686, 41976]),
#  tensor([  262, 34686, 41976,    13]),
#  tensor([34686, 41976,    13,   357]),
#  tensor([41976,    13,   357, 10915]),
#  tensor([   13,   357, 10915,   314]),
#  tensor([  357, 10915,   314,  2138]),
#  tensor([10915,   314,  2138,  1807]),
#  tensor([ 314, 2138, 1807,  340]),
#  tensor([2138, 1807,  340,  561]),
#  tensor([1807,  340,  561,  423]),
#  tensor([340, 561, 423, 587]),
#  tensor([  561,   423,   587, 10598]),
#  tensor([  423,   587, 10598,   393]),
#  tensor([  587, 10598,   393, 28537]),
#  tensor([10598,   393, 28537,  2014]),
#  tensor([  393, 28537,  2014,   198]),
#  tensor([28537,  2014,   198,   198]),
#  tensor([2014,  198,  198,    1]),
#  tensor([198, 198,   1, 464]),
#  tensor([ 198,    1,  464, 6001]),
#  tensor([   1,  464, 6001,  286]),
#  tensor([ 464, 6001,  286,  465]),
#  tensor([ 6001,   286,   465, 13476]),
#  tensor([  286,   465, 13476,     1]),
#  tensor([  465, 13476,     1,   438]),
#  tensor([13476,     1,   438,  5562]),
#  tensor([   1,  438, 5562,  373]),
#  tensor([ 438, 5562,  373,  644]),
#  tensor([5562,  373,  644,  262]),
#  tensor([ 373,  644,  262, 1466]),
#  tensor([ 644,  262, 1466, 1444]),
#  tensor([ 262, 1466, 1444,  340]),
#  tensor([1466, 1444,  340,   13]),
#  tensor([1444,  340,   13,  314]),
#  tensor([340,  13, 314, 460]),
#  tensor([  13,  314,  460, 3285]),
#  tensor([ 314,  460, 3285, 9074]),
#  tensor([ 460, 3285, 9074,   13]),
#  tensor([ 3285,  9074,    13, 46606]),
#  tensor([ 9074,    13, 46606,   536]),
#  tensor([   13, 46606,   536,  5469]),
#  tensor([46606,   536,  5469,   438]),
#  tensor([  536,  5469,   438, 14363]),
#  tensor([ 5469,   438, 14363,   938]),
#  tensor([  438, 14363,   938,  4842]),
#  tensor([14363,   938,  4842,  1650]),
#  tensor([ 938, 4842, 1650,  353]),
#  tensor([4842, 1650,  353,  438]),
#  tensor([1650,  353,  438, 2934]),
#  tensor([ 353,  438, 2934,  489]),
#  tensor([ 438, 2934,  489, 3255]),
#  tensor([2934,  489, 3255,  465]),
#  tensor([  489,  3255,   465, 48422]),
#  tensor([ 3255,   465, 48422,   540]),
#  tensor([  465, 48422,   540,   450]),
#  tensor([48422,   540,   450,    67]),
#  tensor([ 540,  450,   67, 3299]),
#  tensor([ 450,   67, 3299,   13]),
#  tensor([  67, 3299,   13,  366]),
#  tensor([3299,   13,  366, 5189]),
#  tensor([  13,  366, 5189, 1781]),
#  tensor([ 366, 5189, 1781,  340]),
#  tensor([5189, 1781,  340,  338]),
#  tensor([1781,  340,  338, 1016]),
#  tensor([ 340,  338, 1016,  284]),
#  tensor([ 338, 1016,  284, 3758]),
#  tensor([1016,  284, 3758,  262]),
#  tensor([ 284, 3758,  262, 1988]),
#  tensor([3758,  262, 1988,  286]),
#  tensor([ 262, 1988,  286,  616]),
#  tensor([1988,  286,  616, 4286]),
#  tensor([ 286,  616, 4286,  705]),
#  tensor([ 616, 4286,  705, 1014]),
#  tensor([4286,  705, 1014,  510]),
#  tensor([ 705, 1014,  510,   26]),
#  tensor([1014,  510,   26,  475]),
#  tensor([510,  26, 475, 314]),
#  tensor([ 26, 475, 314, 836]),
#  tensor([475, 314, 836, 470]),
#  tensor([314, 836, 470, 892]),
#  tensor([836, 470, 892, 286]),
#  tensor([470, 892, 286, 326]),
#  tensor([892, 286, 326,  11]),
#  tensor([ 286,  326,   11, 1770]),
#  tensor([ 326,   11, 1770,   13]),
#  tensor([  11, 1770,   13, 8759]),
#  tensor([1770,   13, 8759, 2763]),
#  tensor([  13, 8759, 2763,  438]),
#  tensor([8759, 2763,  438, 1169]),
#  tensor([2763,  438, 1169, 2994]),
#  tensor([ 438, 1169, 2994,  284]),
#  tensor([1169, 2994,  284,  943]),
#  tensor([ 2994,   284,   943, 17034]),
#  tensor([  284,   943, 17034,   318]),
#  tensor([  943, 17034,   318,   477]),
#  tensor([17034,   318,   477,   314]),
#  tensor([318, 477, 314, 892]),
#  tensor([477, 314, 892, 286]),
#  tensor([314, 892, 286, 526]),
#  tensor([892, 286, 526, 383]),
#  tensor([ 286,  526,  383, 1573]),
#  tensor([ 526,  383, 1573,   11]),
#  tensor([ 383, 1573,   11,  319]),
#  tensor([1573,   11,  319, 9074]),
#  tensor([  11,  319, 9074,   13]),
#  tensor([ 319, 9074,   13,  536]),
#  tensor([9074,   13,  536, 5469]),
#  tensor([  13,  536, 5469,  338]),
#  tensor([  536,  5469,   338, 11914]),
#  tensor([ 5469,   338, 11914,    11]),
#  tensor([  338, 11914,    11, 33096]),
#  tensor([11914,    11, 33096,   663]),
#  tensor([   11, 33096,   663,  4808]),
#  tensor([33096,   663,  4808,  3808]),
#  tensor([ 663, 4808, 3808,   62]),
#  tensor([4808, 3808,   62,  355]),
#  tensor([3808,   62,  355,  996]),
#  tensor([ 62, 355, 996, 484]),
#  tensor([355, 996, 484, 547]),
#  tensor([  996,   484,   547, 12548]),
#  tensor([  484,   547, 12548,   287]),
#  tensor([  547, 12548,   287,   281]),
#  tensor([12548,   287,   281, 13079]),
#  tensor([  287,   281, 13079,   410]),
#  tensor([  281, 13079,   410, 12523]),
#  tensor([13079,   410, 12523,   286]),
#  tensor([  410, 12523,   286, 22353]),
#  tensor([12523,   286, 22353,    13]),
#  tensor([  286, 22353,    13,   843]),
#  tensor([22353,    13,   843,   340]),
#  tensor([ 13, 843, 340, 373]),
#  tensor([843, 340, 373, 407]),
#  tensor([340, 373, 407, 691]),
#  tensor([373, 407, 691, 262]),
#  tensor([ 407,  691,  262, 9074]),
#  tensor([ 691,  262, 9074,   13]),
#  tensor([ 262, 9074,   13,  536]),
#  tensor([ 9074,    13,   536, 48819]),
#  tensor([   13,   536, 48819,   508]),
#  tensor([  536, 48819,   508, 25722]),
#  tensor([48819,   508, 25722,   276]),
#  tensor([  508, 25722,   276,    13]),
#  tensor([25722,   276,    13, 11161]),
#  tensor([  276,    13, 11161,   407]),
#  tensor([   13, 11161,   407,   262]),
#  tensor([11161,   407,   262, 40123]),
#  tensor([  407,   262, 40123, 18113]),
#  tensor([  262, 40123, 18113,   544]),
#  tensor([40123, 18113,   544,  9325]),
#  tensor([18113,   544,  9325,   701]),
#  tensor([ 544, 9325,  701,   11]),
#  tensor([9325,  701,   11,  379]),
#  tensor([701,  11, 379, 262]),
#  tensor([ 11, 379, 262, 938]),
#  tensor([379, 262, 938, 402]),
#  tensor([ 262,  938,  402, 1617]),
#  tensor([ 938,  402, 1617,  261]),
#  tensor([  402,  1617,   261, 12917]),
#  tensor([ 1617,   261, 12917,   905]),
#  tensor([  261, 12917,   905,    11]),
#  tensor([12917,   905,    11,  5025]),
#  tensor([ 905,   11, 5025,  502]),
#  tensor([  11, 5025,  502,  878]),
#  tensor([5025,  502,  878,  402]),
#  tensor([502, 878, 402, 271]),
#  tensor([  878,   402,   271, 10899]),
#  tensor([  402,   271, 10899,   338]),
#  tensor([  271, 10899,   338,   366]),
#  tensor([10899,   338,   366, 31640]),
#  tensor([  338,   366, 31640,    12]),
#  tensor([  366, 31640,    12,    67]),
#  tensor([31640,    12,    67, 20811]),
#  tensor([   12,    67, 20811,     1]),
#  tensor([   67, 20811,     1,   284]),
#  tensor([20811,     1,   284,   910]),
#  tensor([  1, 284, 910,  11]),
#  tensor([284, 910,  11, 351]),
#  tensor([  910,    11,   351, 10953]),
#  tensor([   11,   351, 10953,   287]),
#  tensor([  351, 10953,   287,   607]),
#  tensor([10953,   287,   607,  2951]),
#  tensor([ 287,  607, 2951,   25]),
#  tensor([ 607, 2951,   25,  366]),
#  tensor([2951,   25,  366, 1135]),
#  tensor([  25,  366, 1135, 2236]),
#  tensor([ 366, 1135, 2236,  407]),
#  tensor([1135, 2236,  407,  804]),
#  tensor([2236,  407,  804, 2402]),
#  tensor([ 407,  804, 2402,  663]),
#  tensor([ 804, 2402,  663,  588]),
#  tensor([2402,  663,  588,  757]),
#  tensor([  663,   588,   757, 13984]),
#  tensor([  588,   757, 13984,   198]),
#  tensor([  757, 13984,   198,   198]),
#  tensor([13984,   198,   198,  5779]),
#  tensor([  198,   198,  5779, 28112]),
#  tensor([  198,  5779, 28112, 10197]),
#  tensor([ 5779, 28112, 10197,   832]),
#  tensor([28112, 10197,   832,   262]),
#  tensor([10197,   832,   262, 46475]),
#  tensor([  832,   262, 46475,   286]),
#  tensor([  262, 46475,   286, 18113]),
#  tensor([46475,   286, 18113,   544]),
#  tensor([  286, 18113,   544,   338]),
#  tensor([18113,   544,   338, 10953]),
#  tensor([  544,   338, 10953,   314]),
#  tensor([  338, 10953,   314,  2936]),
#  tensor([10953,   314,  2936,  1498]),
#  tensor([ 314, 2936, 1498,  284]),
#  tensor([2936, 1498,  284, 1986]),
#  tensor([1498,  284, 1986,  262]),
#  tensor([ 284, 1986,  262, 1109]),
#  tensor([1986,  262, 1109,  351]),
#  tensor([ 262, 1109,  351, 1602]),
#  tensor([ 1109,   351,  1602, 11227]),
#  tensor([  351,  1602, 11227,   414]),
#  tensor([ 1602, 11227,   414,    13]),
#  tensor([11227,   414,    13, 23676]),
#  tensor([  414,    13, 23676,  3619]),
#  tensor([   13, 23676,  3619,   402]),
#  tensor([23676,  3619,   402,   271]),
#  tensor([ 3619,   402,   271, 10899]),
#  tensor([  402,   271, 10899,     0]),
#  tensor([  271, 10899,     0,   383]),
#  tensor([10899,     0,   383,  1466]),
#  tensor([   0,  383, 1466,  550]),
#  tensor([ 383, 1466,  550,  925]),
#  tensor([1466,  550,  925,  683]),
#  tensor([550, 925, 683, 438]),
#  tensor([925, 683, 438, 270]),
#  tensor([683, 438, 270, 373]),
#  tensor([  438,   270,   373, 15830]),
#  tensor([  270,   373, 15830,   326]),
#  tensor([  373, 15830,   326,   484]),
#  tensor([15830,   326,   484,   815]),
#  tensor([  326,   484,   815, 25722]),
#  tensor([  484,   815, 25722,   683]),
#  tensor([  815, 25722,   683,    13]),
#  tensor([25722,   683,    13,  9754]),
#  tensor([ 683,   13, 9754,  465]),
#  tensor([  13, 9754,  465,  898]),
#  tensor([9754,  465,  898, 1714]),
#  tensor([ 465,  898, 1714, 7380]),
#  tensor([  898,  1714,  7380, 30090]),
#  tensor([ 1714,  7380, 30090,   547]),
#  tensor([ 7380, 30090,   547,  2982]),
#  tensor([30090,   547,  2982,    11]),
#  tensor([ 547, 2982,   11,  290]),
#  tensor([2982,   11,  290,  287]),
#  tensor([ 11, 290, 287, 465]),
#  tensor([290, 287, 465, 898]),
#  tensor([ 287,  465,  898, 3292]),
#  tensor([ 465,  898, 3292, 8941]),
#  tensor([ 898, 3292, 8941,  257]),
#  tensor([3292, 8941,  257, 4636]),
#  tensor([ 8941,   257,  4636, 28582]),
#  tensor([  257,  4636, 28582,    13]),
#  tensor([ 4636, 28582,    13, 18612]),
#  tensor([28582,    13, 18612, 35394]),
#  tensor([   13, 18612, 35394,    30]),
#  tensor([18612, 35394,    30,  8673]),
#  tensor([35394,    30,  8673,    13]),
#  tensor([  30, 8673,   13, 1002]),
#  tensor([8673,   13, 1002,  340]),
#  tensor([  13, 1002,  340,  547]),
#  tensor([1002,  340,  547,   11]),
#  tensor([340, 547,  11, 262]),
#  tensor([  547,    11,   262, 15393]),
#  tensor([   11,   262, 15393,   286]),
#  tensor([  262, 15393,   286,   262]),
#  tensor([15393,   286,   262,  5977]),
#  tensor([ 286,  262, 5977,  373]),
#  tensor([  262,  5977,   373, 29178]),
#  tensor([ 5977,   373, 29178,  3474]),
#  tensor([  373, 29178,  3474,   416]),
#  tensor([29178,  3474,   416,  1310]),
#  tensor([ 3474,   416,  1310, 40559]),
#  tensor([  416,  1310, 40559, 11959]),
#  tensor([ 1310, 40559, 11959,  1636]),
#  tensor([40559, 11959,  1636,    11]),
#  tensor([11959,  1636,    11,   508]),
#  tensor([1636,   11,  508,   11]),
#  tensor([ 11, 508,  11, 287]),
#  tensor([508,  11, 287, 477]),
#  tensor([ 11, 287, 477, 922]),
#  tensor([ 287,  477,  922, 4562]),
#  tensor([ 477,  922, 4562,   11]),
#  tensor([ 922, 4562,   11, 3181]),
#  tensor([4562,   11, 3181,  503]),
#  tensor([  11, 3181,  503,  287]),
#  tensor([3181,  503,  287,  262]),
#  tensor([  503,   287,   262, 37090]),
#  tensor([  287,   262, 37090,   257]),
#  tensor([  262, 37090,   257,   845]),
#  tensor([37090,   257,   845, 22665]),
#  tensor([  257,   845, 22665,   366]),
#  tensor([  845, 22665,   366,   672]),
#  tensor([22665,   366,   672,   270]),
#  tensor([ 366,  672,  270, 2838]),
#  tensor([ 672,  270, 2838,    1]),
#  tensor([ 270, 2838,    1,  319]),
#  tensor([2838,    1,  319, 3619]),
#  tensor([   1,  319, 3619,  438]),
#  tensor([ 319, 3619,  438,  505]),
#  tensor([3619,  438,  505,  286]),
#  tensor([438, 505, 286, 883]),
#  tensor([505, 286, 883, 905]),
#  tensor([286, 883, 905,  88]),
#  tensor([ 883,  905,   88, 6685]),
#  tensor([  905,    88,  6685, 42070]),
#  tensor([   88,  6685, 42070,   351]),
#  tensor([ 6685, 42070,   351,  4738]),
#  tensor([42070,   351,  4738,  6276]),
#  tensor([ 351, 4738, 6276,  871]),
#  tensor([4738, 6276,  871,  326]),
#  tensor([6276,  871,  326,  314]),
#  tensor([871, 326, 314, 423]),
#  tensor([ 326,  314,  423, 2982]),
#  tensor([ 314,  423, 2982,  357]),
#  tensor([ 423, 2982,  357,   40]),
#  tensor([2982,  357,   40, 1839]),
#  tensor([ 357,   40, 1839,  470]),
#  tensor([  40, 1839,  470,  910]),
#  tensor([1839,  470,  910,  416]),
#  tensor([ 470,  910,  416, 4150]),
#  tensor([ 910,  416, 4150,    8]),
#  tensor([ 416, 4150,    8, 3688]),
#  tensor([4150,    8, 3688,  284]),
#  tensor([   8, 3688,  284,  402]),
#  tensor([3688,  284,  402,  271]),
#  tensor([  284,   402,   271, 10899]),
#  tensor([  402,   271, 10899,   338]),
#  tensor([  271, 10899,   338, 12036]),
#  tensor([10899,   338, 12036,    13]),
#  tensor([  338, 12036,    13,   843]),
#  tensor([12036,    13,   843,   523]),
#  tensor([ 13, 843, 523, 438]),
#  tensor([  843,   523,   438, 14363]),
#  tensor([  523,   438, 14363, 10568]),
#  tensor([  438, 14363, 10568,   852]),
#  tensor([14363, 10568,   852,  5729]),
#  tensor([10568,   852,  5729, 11331]),
#  tensor([  852,  5729, 11331, 18893]),
#  tensor([ 5729, 11331, 18893,   540]),
#  tensor([11331, 18893,   540,   438]),
#  tensor([18893,   540,   438,  1169]),
#  tensor([ 540,  438, 1169, 5114]),
#  tensor([  438,  1169,  5114, 11835]),
#  tensor([ 1169,  5114, 11835,  3724]),
#  tensor([ 5114, 11835,  3724,   503]),
#  tensor([11835,  3724,   503,    11]),
#  tensor([3724,  503,   11,  290]),
#  tensor([503,  11, 290,  11]),
#  tensor([ 11, 290,  11, 355]),
#  tensor([ 290,   11,  355, 9074]),
#  tensor([  11,  355, 9074,   13]),
#  tensor([ 355, 9074,   13,  536]),
#  tensor([9074,   13,  536, 5469]),
#  tensor([  13,  536, 5469,  550]),
#  tensor([  536,  5469,   550, 11001]),
#  tensor([ 5469,   550, 11001,    11]),
#  tensor([  550, 11001,    11,   262]),
#  tensor([11001,    11,   262,  2756]),
#  tensor([  11,  262, 2756,  286]),
#  tensor([ 262, 2756,  286,  366]),
#  tensor([2756,  286,  366,   38]),
#  tensor([286, 366,  38, 271]),
#  tensor([  366,    38,   271, 10899]),
#  tensor([   38,   271, 10899,    82]),
#  tensor([  271, 10899,    82,     1]),
#  tensor([10899,    82,     1,  1816]),
#  tensor([  82,    1, 1816,  510]),
#  tensor([   1, 1816,  510,   13]),
#  tensor([1816,  510,   13,  198]),
#  tensor([510,  13, 198, 198]),
#  tensor([  13,  198,  198, 1026]),
#  tensor([ 198,  198, 1026,  373]),
#  tensor([ 198, 1026,  373,  407]),
#  tensor([ 1026,   373,   407, 10597]),
#  tensor([  373,   407, 10597,  1115]),
#  tensor([  407, 10597,  1115,   812]),
#  tensor([10597,  1115,   812,  1568]),
#  tensor([1115,  812, 1568,  326]),
#  tensor([ 812, 1568,  326,   11]),
#  tensor([1568,  326,   11,  287]),
#  tensor([326,  11, 287, 262]),
#  tensor([  11,  287,  262, 1781]),
#  tensor([ 287,  262, 1781,  286]),
#  tensor([ 262, 1781,  286,  257]),
#  tensor([1781,  286,  257, 1178]),
#  tensor([ 286,  257, 1178, 2745]),
#  tensor([ 257, 1178, 2745,    6]),
#  tensor([1178, 2745,    6, 4686]),
#  tensor([2745,    6, 4686, 1359]),
#  tensor([   6, 4686, 1359,  319]),
#  tensor([4686, 1359,  319,  262]),
#  tensor([ 1359,   319,   262, 34686]),
#  tensor([  319,   262, 34686, 41976]),
#  tensor([  262, 34686, 41976,    11]),
#  tensor([34686, 41976,    11,   340]),
#  tensor([41976,    11,   340,  6451]),
#  tensor([  11,  340, 6451, 5091]),
#  tensor([ 340, 6451, 5091,  284]),
#  tensor([6451, 5091,  284,  502]),
#  tensor([5091,  284,  502,  284]),
#  tensor([ 284,  502,  284, 4240]),
#  tensor([ 502,  284, 4240, 1521]),
#  tensor([ 284, 4240, 1521,  402]),
#  tensor([4240, 1521,  402,  271]),
#  tensor([ 1521,   402,   271, 10899]),
#  tensor([  402,   271, 10899,   550]),
#  tensor([  271, 10899,   550,  1813]),
#  tensor([10899,   550,  1813,   510]),
#  tensor([ 550, 1813,  510,  465]),
#  tensor([ 1813,   510,   465, 12036]),
#  tensor([  510,   465, 12036,    13]),
#  tensor([  465, 12036,    13,  1550]),
#  tensor([12036,    13,  1550, 14580]),
#  tensor([   13,  1550, 14580,    11]),
#  tensor([ 1550, 14580,    11,   340]),
#  tensor([14580,    11,   340,  1107]),
#  tensor([  11,  340, 1107,  373]),
#  tensor([ 340, 1107,  373,  257]),
#  tensor([ 1107,   373,   257, 29850]),
#  tensor([  373,   257, 29850,  1917]),
#  tensor([  257, 29850,  1917,    13]),
#  tensor([29850,  1917,    13,  1675]),
#  tensor([ 1917,    13,  1675, 24456]),
#  tensor([   13,  1675, 24456,   465]),
#  tensor([ 1675, 24456,   465,  3656]),
#  tensor([24456,   465,  3656,   561]),
#  tensor([ 465, 3656,  561,  423]),
#  tensor([3656,  561,  423,  587]),
#  tensor([ 561,  423,  587, 1165]),
#  tensor([ 423,  587, 1165, 2562]),
#  tensor([ 587, 1165, 2562,  438]),
#  tensor([ 1165,  2562,   438, 14363]),
#  tensor([ 2562,   438, 14363,  3148]),
#  tensor([  438, 14363,  3148,  1650]),
#  tensor([14363,  3148,  1650,  1010]),
#  tensor([3148, 1650, 1010,  550]),
#  tensor([1650, 1010,  550,  587]),
#  tensor([1010,  550,  587, 6699]),
#  tensor([ 550,  587, 6699,  262]),
#  tensor([ 587, 6699,  262, 1540]),
#  tensor([6699,  262, 1540,  558]),
#  tensor([ 262, 1540,  558,  286]),
#  tensor([1540,  558,  286, 2282]),
#  tensor([ 558,  286, 2282,  326]),
#  tensor([ 286, 2282,  326, 9074]),
#  tensor([2282,  326, 9074,   13]),
#  tensor([ 326, 9074,   13,  402]),
#  tensor([9074,   13,  402,  271]),
#  tensor([   13,   402,   271, 10899]),
#  tensor([  402,   271, 10899,   550]),
#  tensor([  271, 10899,   550,   366]),
#  tensor([10899,   550,   366,  7109]),
#  tensor([  550,   366,  7109, 14655]),
#  tensor([  366,  7109, 14655,   683]),
#  tensor([ 7109, 14655,   683,   866]),
#  tensor([14655,   683,   866,   526]),
#  tensor([ 683,  866,  526, 1114]),
#  tensor([ 866,  526, 1114, 9074]),
#  tensor([ 526, 1114, 9074,   13]),
#  tensor([1114, 9074,   13,  402]),
#  tensor([9074,   13,  402,  271]),
#  tensor([   13,   402,   271, 10899]),
#  tensor([  402,   271, 10899,   438]),
#  tensor([  271, 10899,   438,   292]),
#  tensor([10899,   438,   292,   884]),
#  tensor([438, 292, 884, 438]),
#  tensor([  292,   884,   438, 18108]),
#  tensor([  884,   438, 18108,   407]),
#  tensor([  438, 18108,   407, 11196]),
#  tensor([18108,   407, 11196, 10597]),
#  tensor([  407, 11196, 10597,  3016]),
#  tensor([11196, 10597,  3016,   257]),
#  tensor([10597,  3016,   257,   614]),
#  tensor([3016,  257,  614,  706]),
#  tensor([ 257,  614,  706, 3619]),
#  tensor([ 614,  706, 3619,  338]),
#  tensor([  706,  3619,   338, 10568]),
#  tensor([ 3619,   338, 10568,   550]),
#  tensor([  338, 10568,   550,   587]),
#  tensor([10568,   550,   587,  2077]),
#  tensor([ 550,  587, 2077,   13]),
#  tensor([ 587, 2077,   13,  632]),
#  tensor([2077,   13,  632, 1244]),
#  tensor([  13,  632, 1244,  307]),
#  tensor([ 632, 1244,  307,  326]),
#  tensor([1244,  307,  326,  339]),
#  tensor([307, 326, 339, 550]),
#  tensor([ 326,  339,  550, 6405]),
#  tensor([ 339,  550, 6405,  607]),
#  tensor([ 550, 6405,  607,  438]),
#  tensor([ 6405,   607,   438, 20777]),
#  tensor([  607,   438, 20777,   339]),
#  tensor([  438, 20777,   339,  8288]),
#  tensor([20777,   339,  8288,   465]),
#  tensor([  339,  8288,   465, 10152]),
#  tensor([ 8288,   465, 10152,   438]),
#  tensor([  465, 10152,   438, 13893]),
#  tensor([10152,   438, 13893,   339]),
#  tensor([  438, 13893,   339,  1422]),
#  tensor([13893,   339,  1422,   470]),
#  tensor([ 339, 1422,  470,  765]),
#  tensor([1422,  470,  765,  284]),
#  tensor([470, 765, 284, 467]),
#  tensor([765, 284, 467, 319]),
#  tensor([  284,   467,   319, 12036]),
#  tensor([  467,   319, 12036,    26]),
#  tensor([  319, 12036,    26,   475]),
#  tensor([12036,    26,   475,   340]),
#  tensor([ 26, 475, 340, 561]),
#  tensor([475, 340, 561, 423]),
#  tensor([340, 561, 423, 587]),
#  tensor([ 561,  423,  587, 1327]),
#  tensor([ 423,  587, 1327,  284]),
#  tensor([ 587, 1327,  284, 5879]),
#  tensor([1327,  284, 5879,  326]),
#  tensor([ 284, 5879,  326,  339]),
#  tensor([5879,  326,  339,  550]),
#  tensor([ 326,  339,  550, 1813]),
#  tensor([ 339,  550, 1813,  510]),
#  tensor([ 550, 1813,  510,  465]),
#  tensor([ 1813,   510,   465, 12036]),
#  tensor([  510,   465, 12036,   780]),
#  tensor([  465, 12036,   780,   339]),
#  tensor([12036,   780,   339,   550]),
#  tensor([ 780,  339,  550, 6405]),
#  tensor([ 339,  550, 6405,  607]),
#  tensor([ 550, 6405,  607,   13]),
#  tensor([6405,  607,   13,  198]),
#  tensor([607,  13, 198, 198]),
#  tensor([  13,  198,  198, 5189]),
#  tensor([ 198,  198, 5189, 1781]),
#  tensor([ 198, 5189, 1781,   11]),
#  tensor([5189, 1781,   11,  611]),
#  tensor([1781,   11,  611,  673]),
#  tensor([ 11, 611, 673, 550]),
#  tensor([611, 673, 550, 407]),
#  tensor([  673,   550,   407, 17901]),
#  tensor([  550,   407, 17901,   683]),
#  tensor([  407, 17901,   683,   866]),
#  tensor([17901,   683,   866,    11]),
#  tensor([683, 866,  11, 673]),
#  tensor([866,  11, 673, 550]),
#  tensor([  11,  673,  550, 8603]),
#  tensor([ 673,  550, 8603,   11]),
#  tensor([ 550, 8603,   11,  355]),
#  tensor([8603,   11,  355, 4544]),
#  tensor([  11,  355, 4544, 9325]),
#  tensor([ 355, 4544, 9325,  701]),
#  tensor([ 4544,  9325,   701, 42397]),
#  tensor([ 9325,   701, 42397,    11]),
#  tensor([  701, 42397,    11,  4054]),
#  tensor([42397,    11,  4054,   284]),
#  tensor([  11, 4054,  284,  366]),
#  tensor([ 4054,   284,   366, 26282]),
#  tensor([  284,   366, 26282,   683]),
#  tensor([  366, 26282,   683,   510]),
#  tensor([26282,   683,   510,     1]),
#  tensor([683, 510,   1, 438]),
#  tensor([ 510,    1,  438, 7091]),
#  tensor([   1,  438, 7091,  550]),
#  tensor([ 438, 7091,  550,  407]),
#  tensor([7091,  550,  407, 2957]),
#  tensor([ 550,  407, 2957,  683]),
#  tensor([ 407, 2957,  683,  736]),
#  tensor([2957,  683,  736,  284]),
#  tensor([683, 736, 284, 262]),
#  tensor([ 736,  284,  262, 1396]),
#  tensor([ 284,  262, 1396,  417]),
#  tensor([ 262, 1396,  417,   13]),
#  tensor([1396,  417,   13, 1675]),
#  tensor([ 417,   13, 1675, 1234]),
#  tensor([  13, 1675, 1234,  262]),
#  tensor([ 1675,  1234,   262, 14093]),
#  tensor([ 1234,   262, 14093,   656]),
#  tensor([  262, 14093,   656,   465]),
#  tensor([14093,   656,   465,  1021]),
#  tensor([ 656,  465, 1021,  757]),
#  tensor([ 465, 1021,  757,  438]),
#  tensor([ 1021,   757,   438, 10919]),
#  tensor([  757,   438, 10919,   257]),
#  tensor([  438, 10919,   257,   410]),
#  tensor([10919,   257,   410,  5040]),
#  tensor([ 257,  410, 5040,  329]),
#  tensor([ 410, 5040,  329,  257]),
#  tensor([5040,  329,  257, 3656]),
#  tensor([ 329,  257, 3656,    0]),
#  tensor([ 257, 3656,    0,  887]),
#  tensor([3656,    0,  887, 9074]),
#  tensor([   0,  887, 9074,   13]),
#  tensor([ 887, 9074,   13,  402]),
#  tensor([9074,   13,  402,  271]),
#  tensor([   13,   402,   271, 10899]),
#  tensor([  402,   271, 10899,  4120]),
#  tensor([  271, 10899,  4120,   284]),
#  tensor([10899,  4120,   284,   423]),
#  tensor([4120,  284,  423,  595]),
#  tensor([284, 423, 595,  67]),
#  tensor([ 423,  595,   67, 1328]),
#  tensor([ 595,   67, 1328,  340]),
#  tensor([  67, 1328,  340,  438]),
#  tensor([1328,  340,  438,  392]),
#  tensor([340, 438, 392, 314]),
#  tensor([ 438,  392,  314, 2936]),
#  tensor([ 392,  314, 2936,  340]),
#  tensor([ 314, 2936,  340, 1244]),
#  tensor([2936,  340, 1244,  307]),
#  tensor([ 340, 1244,  307, 3499]),
#  tensor([1244,  307, 3499,  284]),
#  tensor([ 307, 3499,  284, 1064]),
#  tensor([3499,  284, 1064,  503]),
#  tensor([ 284, 1064,  503, 1521]),
#  tensor([1064,  503, 1521,   13]),
#  tensor([ 503, 1521,   13,  198]),
#  tensor([1521,   13,  198,  198]),
#  tensor([ 13, 198, 198, 464]),
#  tensor([198, 198, 464, 748]),
#  tensor([198, 464, 748, 586]),
#  tensor([464, 748, 586, 652]),
#  tensor([ 748,  586,  652, 1204]),
#  tensor([ 586,  652, 1204,  286]),
#  tensor([ 652, 1204,  286,  262]),
#  tensor([ 1204,   286,   262, 34686]),
#  tensor([  286,   262, 34686, 41976]),
#  tensor([  262, 34686, 41976, 37733]),
#  tensor([34686, 41976, 37733,  2346]),
#  tensor([41976, 37733,  2346,   284]),
#  tensor([37733,  2346,   284,   884]),
#  tensor([ 2346,   284,   884, 14177]),
#  tensor([  284,   884, 14177,  8233]),
#  tensor([  884, 14177,  8233,  1020]),
#  tensor([14177,  8233,  1020,  5768]),
#  tensor([8233, 1020, 5768,   26]),
#  tensor([1020, 5768,   26,  290]),
#  tensor([5768,   26,  290, 1719]),
#  tensor([  26,  290, 1719,   11]),
#  tensor([ 290, 1719,   11,  319]),
#  tensor([1719,   11,  319,  616]),
#  tensor([ 11, 319, 616, 835]),
#  tensor([319, 616, 835, 284]),
#  tensor([  616,   835,   284, 22489]),
#  tensor([  835,   284, 22489, 40089]),
#  tensor([  284, 22489, 40089,    11]),
#  tensor([22489, 40089,    11,  4978]),
#  tensor([40089,    11,  4978,   257]),
#  tensor([   11,  4978,   257, 19350]),
#  tensor([ 4978,   257, 19350,   286]),
#  tensor([  257, 19350,   286,  3619]),
#  tensor([19350,   286,  3619,   338]),
#  tensor([ 286, 3619,  338, 3652]),
#  tensor([3619,  338, 3652,  436]),
#  tensor([ 338, 3652,  436,   81]),
#  tensor([3652,  436,   81, 5286]),
#  tensor([ 436,   81, 5286, 8812]),
#  tensor([  81, 5286, 8812, 2114]),
#  tensor([5286, 8812, 2114, 1022]),
#  tensor([8812, 2114, 1022,  262]),
#  tensor([2114, 1022,  262,  279]),
#  tensor([1022,  262,  279, 1127]),
#  tensor([ 262,  279, 1127,   11]),
#  tensor([ 279, 1127,   11,  314]),
#  tensor([1127,   11,  314,  550]),
#  tensor([  11,  314,  550, 3589]),
#  tensor([  314,   550,  3589, 28068]),
#  tensor([  550,  3589, 28068,   294]),
#  tensor([ 3589, 28068,   294,  1555]),
#  tensor([28068,   294,  1555,   262]),
#  tensor([ 294, 1555,  262, 1306]),
#  tensor([1555,  262, 1306, 1110]),
#  tensor([ 262, 1306, 1110,   13]),
#  tensor([1306, 1110,   13,  198]),
#  tensor([1110,   13,  198,  198]),
#  tensor([ 13, 198, 198,  40]),
#  tensor([ 198,  198,   40, 1043]),
#  tensor([ 198,   40, 1043,  262]),
#  tensor([  40, 1043,  262, 3155]),
#  tensor([1043,  262, 3155,  379]),
#  tensor([ 262, 3155,  379, 8887]),
#  tensor([ 3155,   379,  8887, 11061]),
#  tensor([  379,  8887, 11061,   511]),
#  tensor([ 8887, 11061,   511, 18057]),
#  tensor([11061,   511, 18057,    12]),
#  tensor([  511, 18057,    12,    83]),
#  tensor([18057,    12,    83,  6037]),
#  tensor([  12,   83, 6037,   26]),
#  tensor([  83, 6037,   26,  290]),
#  tensor([6037,   26,  290, 9074]),
#  tensor([  26,  290, 9074,   13]),
#  tensor([ 290, 9074,   13,  402]),
#  tensor([9074,   13,  402,  271]),
#  tensor([   13,   402,   271, 10899]),
#  tensor([  402,   271, 10899,   338]),
#  tensor([  271, 10899,   338,  7062]),
#  tensor([10899,   338,  7062,   373]),
#  tensor([ 338, 7062,  373,  523]),
#  tensor([7062,  373,  523, 2429]),
#  tensor([ 373,  523, 2429,  498]),
#  tensor([ 523, 2429,  498,  326]),
#  tensor([2429,  498,  326,   11]),
#  tensor([498, 326,  11, 287]),
#  tensor([326,  11, 287, 262]),
#  tensor([   11,   287,   262, 29543]),
#  tensor([  287,   262, 29543,  2745]),
#  tensor([  262, 29543,  2745,    11]),
#  tensor([29543,  2745,    11,   314]),
#  tensor([2745,   11,  314, 4752]),
#  tensor([  11,  314, 4752,  340]),
#  tensor([ 314, 4752,  340, 6777]),
#  tensor([4752,  340, 6777,   13]),
#  tensor([ 340, 6777,   13,  632]),
#  tensor([6777,   13,  632,  373]),
#  tensor([ 13, 632, 373, 407]),
#  tensor([632, 373, 407, 326]),
#  tensor([373, 407, 326, 616]),
#  tensor([ 407,  326,  616, 2583]),
#  tensor([ 326,  616, 2583,  408]),
#  tensor([ 616, 2583,  408,  373]),
#  tensor([2583,  408,  373,  366]),
#  tensor([  408,   373,   366, 47914]),
#  tensor([  373,   366, 47914,  1298]),
#  tensor([  366, 47914,  1298,   319]),
#  tensor([47914,  1298,   319,   326]),
#  tensor([1298,  319,  326,  966]),
#  tensor([319, 326, 966, 314]),
#  tensor([326, 966, 314, 714]),
#  tensor([966, 314, 714, 423]),
#  tensor([ 314,  714,  423, 1813]),
#  tensor([ 714,  423, 1813, 4544]),
#  tensor([ 423, 1813, 4544, 9325]),
#  tensor([1813, 4544, 9325,  701]),
#  tensor([4544, 9325,  701,  262]),
#  tensor([ 9325,   701,   262, 40830]),
#  tensor([  701,   262, 40830, 12719]),
#  tensor([  262, 40830, 12719,  3874]),
#  tensor([40830, 12719,  3874,    13]),
#  tensor([12719,  3874,    13,   632]),
#  tensor([3874,   13,  632,  373]),
#  tensor([ 13, 632, 373, 655]),
#  tensor([632, 373, 655, 780]),
#  tensor([373, 655, 780, 673]),
#  tensor([655, 780, 673, 373]),
#  tensor([ 780,  673,  373, 4808]),
#  tensor([ 673,  373, 4808, 1662]),
#  tensor([ 373, 4808, 1662,   62]),
#  tensor([4808, 1662,   62, 3499]),
#  tensor([1662,   62, 3499,  438]),
#  tensor([  62, 3499,  438,  361]),
#  tensor([3499,  438,  361,  314]),
#  tensor([438, 361, 314, 743]),
#  tensor([361, 314, 743, 307]),
#  tensor([  314,   743,   307, 41746]),
#  tensor([  743,   307, 41746, 12004]),
#  tensor([  307, 41746, 12004,   262]),
#  tensor([41746, 12004,   262,  6473]),
#  tensor([12004,   262,  6473,   438]),
#  tensor([ 262, 6473,  438, 5562]),
#  tensor([6473,  438, 5562,  314]),
#  tensor([ 438, 5562,  314, 1043]),
#  tensor([5562,  314, 1043,  607]),
#  tensor([ 314, 1043,  607,  523]),
#  tensor([1043,  607,  523,   13]),
#  tensor([ 607,  523,   13, 1114]),
#  tensor([ 523,   13, 1114, 3619]),
#  tensor([  13, 1114, 3619,   11]),
#  tensor([1114, 3619,   11,  477]),
#  tensor([3619,   11,  477,  465]),
#  tensor([  11,  477,  465, 1204]),
#  tensor([ 477,  465, 1204,   11]),
#  tensor([ 465, 1204,   11,  550]),
#  tensor([1204,   11,  550,  587]),
#  tensor([   11,   550,   587, 11191]),
#  tensor([  550,   587, 11191,   416]),
#  tensor([  587, 11191,   416,  3499]),
#  tensor([11191,   416,  3499,  1466]),
#  tensor([ 416, 3499, 1466,   25]),
#  tensor([3499, 1466,   25,  484]),
#  tensor([1466,   25,  484,  550]),
#  tensor([   25,   484,   550, 26546]),
#  tensor([  484,   550, 26546,  1068]),
#  tensor([  550, 26546,  1068,   465]),
#  tensor([26546,  1068,   465,  1242]),
#  tensor([1068,  465, 1242,   11]),
#  tensor([ 465, 1242,   11,  340]),
#  tensor([1242,   11,  340,  550]),
#  tensor([ 11, 340, 550, 587]),
#  tensor([340, 550, 587, 302]),
#  tensor([ 550,  587,  302, 1144]),
#  tensor([ 587,  302, 1144,  287]),
#  tensor([ 302, 1144,  287,  262]),
#  tensor([1144,  287,  262, 3024]),
#  tensor([ 287,  262, 3024,   12]),
#  tensor([ 262, 3024,   12, 4803]),
#  tensor([3024,   12, 4803,  286]),
#  tensor([  12, 4803,  286,  511]),
#  tensor([4803,  286,  511,  512]),
#  tensor([ 286,  511,  512, 1741]),
#  tensor([ 511,  512, 1741,   13]),
#  tensor([ 512, 1741,   13,  843]),
#  tensor([1741,   13,  843,  340]),
#  tensor([ 13, 843, 340, 373]),
#  tensor([ 843,  340,  373, 4361]),
#  tensor([ 340,  373, 4361, 5048]),
#  tensor([ 373, 4361, 5048,  425]),
#  tensor([4361, 5048,  425,  284]),
#  tensor([5048,  425,  284, 3465]),
#  tensor([ 425,  284, 3465,  644]),
#  tensor([ 284, 3465,  644, 1245]),
#  tensor([3465,  644, 1245,  262]),
#  tensor([ 644, 1245,  262,  366]),
#  tensor([ 1245,   262,   366, 25124]),
#  tensor([  262,   366, 25124,  3101]),
#  tensor([  366, 25124,  3101,  8137]),
#  tensor([25124,  3101,  8137,   286]),
#  tensor([ 3101,  8137,   286, 16957]),
#  tensor([ 8137,   286, 16957,  1696]),
#  tensor([  286, 16957,  1696,   414]),
#  tensor([16957,  1696,   414,     1]),
#  tensor([1696,  414,    1,  357]),
#  tensor([414,   1, 357,  40]),
#  tensor([   1,  357,   40, 9577]),
#  tensor([ 357,   40, 9577, 4544]),
#  tensor([  40, 9577, 4544, 9325]),
#  tensor([9577, 4544, 9325,  701]),
#  tensor([4544, 9325,  701,    8]),
#  tensor([9325,  701,    8,  373]),
#  tensor([ 701,    8,  373, 1719]),
#  tensor([   8,  373, 1719,  319]),
#  tensor([ 373, 1719,  319,  683]),
#  tensor([1719,  319,  683,   13]),
#  tensor([319, 683,  13, 198]),
#  tensor([683,  13, 198, 198]),
#  tensor([ 13, 198, 198,  40]),
#  tensor([198, 198,  40, 423]),
#  tensor([ 198,   40,  423, 4750]),
#  tensor([  40,  423, 4750,  326]),
#  tensor([ 423, 4750,  326, 9074]),
#  tensor([4750,  326, 9074,   13]),
#  tensor([ 326, 9074,   13,  402]),
#  tensor([9074,   13,  402,  271]),
#  tensor([   13,   402,   271, 10899]),
#  tensor([  402,   271, 10899,   373]),
#  tensor([  271, 10899,   373,  5527]),
#  tensor([10899,   373,  5527,    26]),
#  tensor([ 373, 5527,   26,  290]),
#  tensor([5527,   26,  290,  340]),
#  tensor([ 26, 290, 340, 373]),
#  tensor([ 290,  340,  373, 3393]),
#  tensor([  340,   373,  3393, 34953]),
#  tensor([  373,  3393, 34953,   856]),
#  tensor([ 3393, 34953,   856,   326]),
#  tensor([34953,   856,   326,   607]),
#  tensor([ 856,  326,  607, 5229]),
#  tensor([ 326,  607, 5229,  373]),
#  tensor([  607,  5229,   373, 37895]),
#  tensor([ 5229,   373, 37895,   422]),
#  tensor([  373, 37895,   422,   428]),
#  tensor([37895,   422,   428, 25179]),
#  tensor([  422,   428, 25179,   257]),
#  tensor([  428, 25179,   257, 19217]),
#  tensor([25179,   257, 19217,   475]),
#  tensor([  257, 19217,   475,  8904]),
#  tensor([19217,   475,  8904, 14676]),
#  tensor([  475,  8904, 14676,    13]),
#  tensor([ 8904, 14676,    13,   632]),
#  tensor([14676,    13,   632,   318]),
#  tensor([ 13, 632, 318,  11]),
#  tensor([632, 318,  11, 355]),
#  tensor([318,  11, 355, 257]),
#  tensor([  11,  355,  257, 3896]),
#  tensor([ 355,  257, 3896,   11]),
#  tensor([ 257, 3896,   11,  262]),
#  tensor([3896,   11,  262,  661]),
#  tensor([ 11, 262, 661, 508]),
#  tensor([  262,   661,   508, 40987]),
#  tensor([  661,   508, 40987,  1637]),
#  tensor([  508, 40987,  1637,   508]),
#  tensor([40987,  1637,   508,   651]),
#  tensor([1637,  508,  651,  749]),
#  tensor([508, 651, 749, 503]),
#  tensor([651, 749, 503, 286]),
#  tensor([749, 503, 286, 340]),
#  tensor([503, 286, 340,  26]),
#  tensor([286, 340,  26, 290]),
#  tensor([ 340,   26,  290, 3619]),
#  tensor([  26,  290, 3619,  338]),
#  tensor([  290,  3619,   338, 19992]),
#  tensor([ 3619,   338, 19992, 31564]),
#  tensor([  338, 19992, 31564,   286]),
#  tensor([19992, 31564,   286,   465]),
#  tensor([31564,   286,   465,  3656]),
#  tensor([ 286,  465, 3656,  338]),
#  tensor([ 465, 3656,  338, 1263]),
#  tensor([3656,  338, 1263, 5236]),
#  tensor([ 338, 1263, 5236, 9343]),
#  tensor([1263, 5236, 9343,  683]),
#  tensor([5236, 9343,  683,   11]),
#  tensor([9343,  683,   11,  351]),
#  tensor([683,  11, 351, 281]),
#  tensor([  11,  351,  281, 5585]),
#  tensor([ 351,  281, 5585,  286]),
#  tensor([ 281, 5585,  286, 2818]),
#  tensor([5585,  286, 2818,  922]),
#  tensor([ 286, 2818,  922,   12]),
#  tensor([ 2818,   922,    12, 49705]),
#  tensor([  922,    12, 49705,    11]),
#  tensor([   12, 49705,    11,   284]),
#  tensor([49705,    11,   284, 21595]),
#  tensor([   11,   284, 21595,  1133]),
#  tensor([  284, 21595,  1133,   340]),
#  tensor([21595,  1133,   340,   656]),
#  tensor([1133,  340,  656, 5563]),
#  tensor([ 340,  656, 5563,  286]),
#  tensor([ 656, 5563,  286, 1242]),
#  tensor([5563,  286, 1242,  290]),
#  tensor([  286,  1242,   290, 13064]),
#  tensor([ 1242,   290, 13064,    13]),
#  tensor([  290, 13064,    13,  1675]),
#  tensor([13064,    13,  1675,   262]),
#  tensor([  13, 1675,  262, 6846]),
#  tensor([1675,  262, 6846,   11]),
#  tensor([ 262, 6846,   11,  314]),
#  tensor([6846,   11,  314, 1276]),
#  tensor([  11,  314, 1276,  751]),
#  tensor([ 314, 1276,  751,   11]),
#  tensor([1276,  751,   11,  339]),
#  tensor([ 751,   11,  339, 6150]),
#  tensor([  11,  339, 6150, 5365]),
#  tensor([  339,  6150,  5365, 31655]),
#  tensor([ 6150,  5365, 31655,    26]),
#  tensor([ 5365, 31655,    26,   475]),
#  tensor([31655,    26,   475,   339]),
#  tensor([ 26, 475, 339, 373]),
#  tensor([ 475,  339,  373, 7067]),
#  tensor([  339,   373,  7067, 29396]),
#  tensor([  373,  7067, 29396, 18443]),
#  tensor([ 7067, 29396, 18443, 12271]),
#  tensor([29396, 18443, 12271,   290]),
#  tensor([18443, 12271,   290, 45592]),
#  tensor([12271,   290, 45592,    12]),
#  tensor([  290, 45592,    12, 14792]),
#  ...]

# %%
tokenizer.decode([dataloader.dataset.input_ids[0][2]])
# Out:
# 'AD'

# %%
raw[:50]
# Out:
# 'I HAD always thought Jack Gisburn rather a cheap g'

# %%
import torch
torch.__version__
# Out:
# '2.9.0+cu128'

# %%
dataloader = create_dataloader_v1(
    raw, batch_size=1, max_len=4, stride=1, shuffle=False
)

data_iter = iter(dataloader)
next(data_iter)
# Out:
# [tensor([[  40,  367, 2885, 1464]]), tensor([[ 367, 2885, 1464, 1807]])]

# %%
next(data_iter)
# Out:
# [tensor([[ 367, 2885, 1464, 1807]]), tensor([[2885, 1464, 1807, 3619]])]

# %%
next(data_iter)
# Out:
# [tensor([[2885, 1464, 1807, 3619]]), tensor([[1464, 1807, 3619,  402]])]

# %%
dataloader = create_dataloader_v1(
    raw, batch_size=8, max_len=4, stride=4, shuffle=False
)

data_iter = iter(dataloader)
inputs, targets = next(data_iter)
print("Inputs:\n", inputs)
print("Targets:\n", targets)
# Out:
# Inputs:
#  tensor([[   40,   367,  2885,  1464],
#         [ 1807,  3619,   402,   271],
#         [10899,  2138,   257,  7026],
#         [15632,   438,  2016,   257],
#         [  922,  5891,  1576,   438],
#         [  568,   340,   373,   645],
#         [ 1049,  5975,   284,   502],
#         [  284,  3285,   326,    11]])
# Targets:
#  tensor([[  367,  2885,  1464,  1807],
#         [ 3619,   402,   271, 10899],
#         [ 2138,   257,  7026, 15632],
#         [  438,  2016,   257,   922],
#         [ 5891,  1576,   438,   568],
#         [  340,   373,   645,  1049],
#         [ 5975,   284,   502,   284],
#         [ 3285,   326,    11,   287]])
